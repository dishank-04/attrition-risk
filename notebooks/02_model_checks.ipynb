# %%
import pandas as pd
from src.paths import FEATURES_TARGETS
from src.models.churn_model import create_churn_pipeline
from src.models.ltv_model import create_ltv_pipeline
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
df = pd.read_csv(FEATURES_TARGETS)
df
# Out:
#       Customer ID  Recency  Frequency  Monetary  Tenure  AvgBasketSize  \
# 0           12346      155         11    372.86     351       6.363636
# 1           12347       30          1    611.53      30     509.000000
# 2           12348       64          1    222.16      64     373.000000
# 3           12349       33          3   2671.14     215     331.000000
# 4           12351        1          1    300.93       1     261.000000
# ...           ...      ...        ...       ...     ...            ...
# 4261        18283        8          6    641.77     284      56.000000
# 4262        18284       57          1    461.68      57     494.000000
# 4263        18285      286          1    427.00     286     145.000000
# 4264        18286      102          2   1296.43     349     304.000000
# 4265        18287        8          4   2345.71     197     356.750000
#
#       Target_LTV  Target_churn
# 0       77183.60             0
# 1        5021.79             0
# ...

# %%
# Checking ltv_model
df_copy = df.copy()

y_ltv = df_copy["Target_LTV"]
y_churn = df_copy["Target_churn"]
df_copy = df_copy.drop(columns=["Target_LTV", "Target_churn"])

linear_regrssion_pipeline = create_ltv_pipeline(LinearRegression())
linear_regrssion_pipeline.fit(df_copy, y_ltv)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('log_features',
#                                                   Pipeline(steps=[('transformer',
#                                                                    FunctionTransformer(func=<ufunc 'log1p'>)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Frequency', 'Monetary',
#                                                    'AvgBasketSize']),
#                                                  ('numeric_features',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Recency', 'Tenure'])],
# ...

# %%
logistic_regression_pipeline = create_churn_pipeline(LogisticRegression())
logistic_regression_pipeline.fit(df_copy, y_churn)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('log_features',
#                                                   Pipeline(steps=[('transformer',
#                                                                    FunctionTransformer(func=<ufunc 'log1p'>)),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Frequency', 'Monetary',
#                                                    'AvgBasketSize']),
#                                                  ('numeric_features',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Recency', 'Tenure'])],
# ...
